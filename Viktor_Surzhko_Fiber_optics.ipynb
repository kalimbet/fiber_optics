# %% [markdown]
# # Fiber optics (optical fiber)
# Fiber optics, or optical fiber, refers to the medium and the technology associated with the transmission of information as light pulses along a glass or plastic strand or fiber. Fiber optics is used long-distance and high-performance data networking.
#
# Fiber optics are also commonly used in telecommunication services such as internet, television and telephones. As an example, companies such as Verizon and Google use fiber optics in their Verizon FIOS and Google Fiber services, providing gigabit internet speeds to users.
#
# Fiber optic cables are used since they hold a number of advantages over copper cables, such as higher bandwidth and transmit speeds
#
# A fiber optic cable can contain a varying number of these glass fibers -- from a few up to a couple hundred. Surrounding the glass fiber core is another glass layer called cladding. A layer known as a buffer tube protects the cladding, and a jacket layer acts as the final protective layer for the individual strand.

# %% [markdown]
# ![image](https://3.imimg.com/data3/SO/HU/MY-3400599/lite-500x500.png)

# %% [markdown]
# ## Problem statement
# Determine whether or not specified materials will form a light pipe.
# If they do form a light pipe, compute the angles at which light can
# enter the pipe and be transmitted.
#
# ![image](http://oer2go.org/mods/en-boundless/figures.boundless-cdn.com/17012/large/figure-2026-04-04.jpeg)
#
# ### Formula: <h1> $\theta_{c} = sin^{-1}\frac{n_{2}}{n_{1}}$ </h1>
#
#
#
# ## Input/output description
# As shown in Table Index of refraction the input to the program is a
# data file containing the indices of refraction for the potential light
# pipes. The output is a message indicating whether or not light is
# transmitted and the angles at which it can enter the pipe.
#
# |Material|Index of refraction|
# |-|-|
# |Hydrogen|	 1.0001|
# |Air|	 1.0003|
# |Carbon dioxide|	 1.0005|
# |Water|	 1.333|
# |Ethyl alcohol|	 1.362|
# |Glycerine|	 1.473|
# |Ice|	 1.31|
# |Polysterene|	 1.59|
# |Crown glass|	 1.50 - 1.62|
# |Flint glass|	 1.57 - 1.75|
# |Diamond|	 2.417|
# |Acrylic|	 1.49|

# %% [markdown]
# ## Solution to this problem

# %% [markdown]
# ### Import libraries

# %%
import numpy as np

# %% [markdown]
# ### Load Data and creation variables

# %%
file = open('data.txt', 'r')
data = file.readlines()
file.close()

numbers = []
names = []

error = 0
approved = 0

# %% [markdown]
# ### Separation of data for subsequent calculations

# %%
for i in data[0:]:    
    if('-' in i):      
        name = i.split('\t')[0]
        number = i.split(':')[1]       
        listNumbers = number.split('-')        
        interval = np.arange(float(listNumbers[0]), float(listNumbers[1]), 0.01)                                
        names.extend([name] * len(interval))
        numbers.extend(interval)       
    else:        
        name = i.split('\t')[0]
        number = i.split(':')[1]
        names.append(name)
        numbers.append(float(number))

# %% [markdown]
# ### Using the formula to get the result

# %%
for i in range(len(names)):
    for j in range(len(numbers)):
        if(i == j):
            continue                 
        if (numbers[i] > numbers[j]):
            print('Light is not transmitted ' )
            print('for rod index {0} {1} and index {2} {3}'.format(names[i], numbers[i], names[j], numbers[j]) + '\n')
            error +=1
            continue
        else:
            angle = round(np.degrees(arcsin), 2)
            arcsin = np.arcsin((numbers[i]) / (numbers[j]))
            print('Light is transmitted ' )
            print('for rod index {0} {1} and index {2} {3}'.format(names[i], numbers[i], names[j], numbers[j]))
            print('Angle: {0}. This light pipe will transmit light for angles of incidence greater than {0}'.format(angle) + '\n')
            approved += 1

print('Here we can see that from {0} the combinations {2} do not transmit light, but {1} have the ability to transmit light.'.format((approved+error), approved, error))
# Out:
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Air: 1.0003
# Angle: 38.06. This light pipe will transmit light for angles of incidence greater than 38.06
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Carbon dioxide: 1.0005
# Angle: 88.85. This light pipe will transmit light for angles of incidence greater than 88.85
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Water: 1.333
# Angle: 88.38. This light pipe will transmit light for angles of incidence greater than 88.38
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Ethyl Alcohol: 1.362
# Angle: 48.61. This light pipe will transmit light for angles of incidence greater than 48.61
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Glycerine: 1.473
# Angle: 47.25. This light pipe will transmit light for angles of incidence greater than 47.25
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Ice: 1.31
# Angle: 42.76. This light pipe will transmit light for angles of incidence greater than 42.76
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Polystyrene: 1.59
# Angle: 49.77. This light pipe will transmit light for angles of incidence greater than 49.77
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.5
# Angle: 38.98. This light pipe will transmit light for angles of incidence greater than 38.98
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.51
# Angle: 41.82. This light pipe will transmit light for angles of incidence greater than 41.82
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.52
# Angle: 41.48. This light pipe will transmit light for angles of incidence greater than 41.48
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.53
# Angle: 41.14. This light pipe will transmit light for angles of incidence greater than 41.14
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.54
# Angle: 40.82. This light pipe will transmit light for angles of incidence greater than 40.82
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.55
# Angle: 40.5. This light pipe will transmit light for angles of incidence greater than 40.5
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.56
# Angle: 40.18. This light pipe will transmit light for angles of incidence greater than 40.18
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.57
# Angle: 39.87. This light pipe will transmit light for angles of incidence greater than 39.87
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.58
# Angle: 39.57. This light pipe will transmit light for angles of incidence greater than 39.57
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.59
# Angle: 39.27. This light pipe will transmit light for angles of incidence greater than 39.27
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.6
# Angle: 38.98. This light pipe will transmit light for angles of incidence greater than 38.98
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.61
# Angle: 38.69. This light pipe will transmit light for angles of incidence greater than 38.69
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Crown glass: 1.62
# Angle: 38.4. This light pipe will transmit light for angles of incidence greater than 38.4
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.57
# Angle: 38.12. This light pipe will transmit light for angles of incidence greater than 38.12
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.58
# Angle: 39.57. This light pipe will transmit light for angles of incidence greater than 39.57
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.59
# Angle: 39.27. This light pipe will transmit light for angles of incidence greater than 39.27
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6
# Angle: 38.98. This light pipe will transmit light for angles of incidence greater than 38.98
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.61
# Angle: 38.69. This light pipe will transmit light for angles of incidence greater than 38.69
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.62
# Angle: 38.4. This light pipe will transmit light for angles of incidence greater than 38.4
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6300000000000001
# Angle: 38.12. This light pipe will transmit light for angles of incidence greater than 38.12
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6400000000000001
# Angle: 37.85. This light pipe will transmit light for angles of incidence greater than 37.85
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6500000000000001
# Angle: 37.58. This light pipe will transmit light for angles of incidence greater than 37.58
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6600000000000001
# Angle: 37.31. This light pipe will transmit light for angles of incidence greater than 37.31
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6700000000000002
# Angle: 37.05. This light pipe will transmit light for angles of incidence greater than 37.05
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6800000000000002
# Angle: 36.79. This light pipe will transmit light for angles of incidence greater than 36.79
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.6900000000000002
# Angle: 36.53. This light pipe will transmit light for angles of incidence greater than 36.53
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.7000000000000002
# Angle: 36.28. This light pipe will transmit light for angles of incidence greater than 36.28
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.7100000000000002
# Angle: 36.04. This light pipe will transmit light for angles of incidence greater than 36.04
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.7200000000000002
# Angle: 35.79. This light pipe will transmit light for angles of incidence greater than 35.79
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.7300000000000002
# Angle: 35.55. This light pipe will transmit light for angles of incidence greater than 35.55
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Flint glass: 1.7400000000000002
# Angle: 35.32. This light pipe will transmit light for angles of incidence greater than 35.32
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Diamond: 2.417
# Angle: 35.08. This light pipe will transmit light for angles of incidence greater than 35.08
#
# Light is transmitted
# for rod index Hydrogen: 1.0001 and index Acrylic: 1.49
# Angle: 24.44. This light pipe will transmit light for angles of incidence greater than 24.44
#
# Light is not transmitted
# for rod index Air: 1.0003 and index Hydrogen: 1.0001
#
# Light is transmitted
# for rod index Air: 1.0003 and index Carbon dioxide: 1.0005
# Angle: 42.16. This light pipe will transmit light for angles of incidence greater than 42.16
#
# Light is transmitted
# for rod index Air: 1.0003 and index Water: 1.333
# Angle: 88.85. This light pipe will transmit light for angles of incidence greater than 88.85
#
# Light is transmitted
# for rod index Air: 1.0003 and index Ethyl Alcohol: 1.362
# Angle: 48.63. This light pipe will transmit light for angles of incidence greater than 48.63
#
# Light is transmitted
# for rod index Air: 1.0003 and index Glycerine: 1.473
# Angle: 47.26. This light pipe will transmit light for angles of incidence greater than 47.26
#
# Light is transmitted
# for rod index Air: 1.0003 and index Ice: 1.31
# Angle: 42.77. This light pipe will transmit light for angles of incidence greater than 42.77
#
# Light is transmitted
# for rod index Air: 1.0003 and index Polystyrene: 1.59
# Angle: 49.78. This light pipe will transmit light for angles of incidence greater than 49.78
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.5
# Angle: 38.99. This light pipe will transmit light for angles of incidence greater than 38.99
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.51
# Angle: 41.83. This light pipe will transmit light for angles of incidence greater than 41.83
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.52
# Angle: 41.49. This light pipe will transmit light for angles of incidence greater than 41.49
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.53
# Angle: 41.15. This light pipe will transmit light for angles of incidence greater than 41.15
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.54
# Angle: 40.83. This light pipe will transmit light for angles of incidence greater than 40.83
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.55
# Angle: 40.51. This light pipe will transmit light for angles of incidence greater than 40.51
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.56
# Angle: 40.19. This light pipe will transmit light for angles of incidence greater than 40.19
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.57
# Angle: 39.88. This light pipe will transmit light for angles of incidence greater than 39.88
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.58
# Angle: 39.58. This light pipe will transmit light for angles of incidence greater than 39.58
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.59
# Angle: 39.28. This light pipe will transmit light for angles of incidence greater than 39.28
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.6
# Angle: 38.99. This light pipe will transmit light for angles of incidence greater than 38.99
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.61
# Angle: 38.7. This light pipe will transmit light for angles of incidence greater than 38.7
#
# Light is transmitted
# for rod index Air: 1.0003 and index Crown glass: 1.62
# Angle: 38.41. This light pipe will transmit light for angles of incidence greater than 38.41
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.57
# Angle: 38.13. This light pipe will transmit light for angles of incidence greater than 38.13
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.58
# Angle: 39.58. This light pipe will transmit light for angles of incidence greater than 39.58
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.59
# Angle: 39.28. This light pipe will transmit light for angles of incidence greater than 39.28
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6
# Angle: 38.99. This light pipe will transmit light for angles of incidence greater than 38.99
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.61
# Angle: 38.7. This light pipe will transmit light for angles of incidence greater than 38.7
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.62
# Angle: 38.41. This light pipe will transmit light for angles of incidence greater than 38.41
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6300000000000001
# Angle: 38.13. This light pipe will transmit light for angles of incidence greater than 38.13
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6400000000000001
# Angle: 37.86. This light pipe will transmit light for angles of incidence greater than 37.86
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6500000000000001
# Angle: 37.59. This light pipe will transmit light for angles of incidence greater than 37.59
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6600000000000001
# Angle: 37.32. This light pipe will transmit light for angles of incidence greater than 37.32
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6700000000000002
# Angle: 37.06. This light pipe will transmit light for angles of incidence greater than 37.06
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6800000000000002
# Angle: 36.8. This light pipe will transmit light for angles of incidence greater than 36.8
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.6900000000000002
# Angle: 36.54. This light pipe will transmit light for angles of incidence greater than 36.54
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.7000000000000002
# Angle: 36.29. This light pipe will transmit light for angles of incidence greater than 36.29
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.7100000000000002
# Angle: 36.04. This light pipe will transmit light for angles of incidence greater than 36.04
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.7200000000000002
# Angle: 35.8. This light pipe will transmit light for angles of incidence greater than 35.8
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.7300000000000002
# Angle: 35.56. This light pipe will transmit light for angles of incidence greater than 35.56
#
# Light is transmitted
# for rod index Air: 1.0003 and index Flint glass: 1.7400000000000002
# Angle: 35.32. This light pipe will transmit light for angles of incidence greater than 35.32
#
# Light is transmitted
# for rod index Air: 1.0003 and index Diamond: 2.417
# Angle: 35.09. This light pipe will transmit light for angles of incidence greater than 35.09
#
# Light is transmitted
# for rod index Air: 1.0003 and index Acrylic: 1.49
# Angle: 24.45. This light pipe will transmit light for angles of incidence greater than 24.45
#
# Light is not transmitted
# for rod index Carbon dioxide: 1.0005 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Carbon dioxide: 1.0005 and index Air: 1.0003
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Water: 1.333
# Angle: 42.17. This light pipe will transmit light for angles of incidence greater than 42.17
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Ethyl Alcohol: 1.362
# Angle: 48.64. This light pipe will transmit light for angles of incidence greater than 48.64
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Glycerine: 1.473
# Angle: 47.27. This light pipe will transmit light for angles of incidence greater than 47.27
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Ice: 1.31
# Angle: 42.78. This light pipe will transmit light for angles of incidence greater than 42.78
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Polystyrene: 1.59
# Angle: 49.8. This light pipe will transmit light for angles of incidence greater than 49.8
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.5
# Angle: 38.99. This light pipe will transmit light for angles of incidence greater than 38.99
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.51
# Angle: 41.84. This light pipe will transmit light for angles of incidence greater than 41.84
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.52
# Angle: 41.5. This light pipe will transmit light for angles of incidence greater than 41.5
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.53
# Angle: 41.16. This light pipe will transmit light for angles of incidence greater than 41.16
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.54
# Angle: 40.84. This light pipe will transmit light for angles of incidence greater than 40.84
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.55
# Angle: 40.52. This light pipe will transmit light for angles of incidence greater than 40.52
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.56
# Angle: 40.2. This light pipe will transmit light for angles of incidence greater than 40.2
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.57
# Angle: 39.89. This light pipe will transmit light for angles of incidence greater than 39.89
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.58
# Angle: 39.59. This light pipe will transmit light for angles of incidence greater than 39.59
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.59
# Angle: 39.29. This light pipe will transmit light for angles of incidence greater than 39.29
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.6
# Angle: 38.99. This light pipe will transmit light for angles of incidence greater than 38.99
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.61
# Angle: 38.71. This light pipe will transmit light for angles of incidence greater than 38.71
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Crown glass: 1.62
# Angle: 38.42. This light pipe will transmit light for angles of incidence greater than 38.42
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.57
# Angle: 38.14. This light pipe will transmit light for angles of incidence greater than 38.14
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.58
# Angle: 39.59. This light pipe will transmit light for angles of incidence greater than 39.59
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.59
# Angle: 39.29. This light pipe will transmit light for angles of incidence greater than 39.29
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6
# Angle: 38.99. This light pipe will transmit light for angles of incidence greater than 38.99
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.61
# Angle: 38.71. This light pipe will transmit light for angles of incidence greater than 38.71
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.62
# Angle: 38.42. This light pipe will transmit light for angles of incidence greater than 38.42
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6300000000000001
# Angle: 38.14. This light pipe will transmit light for angles of incidence greater than 38.14
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6400000000000001
# Angle: 37.87. This light pipe will transmit light for angles of incidence greater than 37.87
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6500000000000001
# Angle: 37.59. This light pipe will transmit light for angles of incidence greater than 37.59
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6600000000000001
# Angle: 37.33. This light pipe will transmit light for angles of incidence greater than 37.33
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6700000000000002
# Angle: 37.06. This light pipe will transmit light for angles of incidence greater than 37.06
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6800000000000002
# Angle: 36.81. This light pipe will transmit light for angles of incidence greater than 36.81
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.6900000000000002
# Angle: 36.55. This light pipe will transmit light for angles of incidence greater than 36.55
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.7000000000000002
# Angle: 36.3. This light pipe will transmit light for angles of incidence greater than 36.3
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.7100000000000002
# Angle: 36.05. This light pipe will transmit light for angles of incidence greater than 36.05
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.7200000000000002
# Angle: 35.81. This light pipe will transmit light for angles of incidence greater than 35.81
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.7300000000000002
# Angle: 35.57. This light pipe will transmit light for angles of incidence greater than 35.57
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Flint glass: 1.7400000000000002
# Angle: 35.33. This light pipe will transmit light for angles of incidence greater than 35.33
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Diamond: 2.417
# Angle: 35.1. This light pipe will transmit light for angles of incidence greater than 35.1
#
# Light is transmitted
# for rod index Carbon dioxide: 1.0005 and index Acrylic: 1.49
# Angle: 24.45. This light pipe will transmit light for angles of incidence greater than 24.45
#
# Light is not transmitted
# for rod index Water: 1.333 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Water: 1.333 and index Air: 1.0003
#
# Light is not transmitted
# for rod index Water: 1.333 and index Carbon dioxide: 1.0005
#
# Light is transmitted
# for rod index Water: 1.333 and index Ethyl Alcohol: 1.362
# Angle: 42.18. This light pipe will transmit light for angles of incidence greater than 42.18
#
# Light is transmitted
# for rod index Water: 1.333 and index Glycerine: 1.473
# Angle: 78.16. This light pipe will transmit light for angles of incidence greater than 78.16
#
# Light is not transmitted
# for rod index Water: 1.333 and index Ice: 1.31
#
# Light is transmitted
# for rod index Water: 1.333 and index Polystyrene: 1.59
# Angle: 64.82. This light pipe will transmit light for angles of incidence greater than 64.82
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.5
# Angle: 56.97. This light pipe will transmit light for angles of incidence greater than 56.97
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.51
# Angle: 62.71. This light pipe will transmit light for angles of incidence greater than 62.71
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.52
# Angle: 61.98. This light pipe will transmit light for angles of incidence greater than 61.98
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.53
# Angle: 61.28. This light pipe will transmit light for angles of incidence greater than 61.28
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.54
# Angle: 60.6. This light pipe will transmit light for angles of incidence greater than 60.6
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.55
# Angle: 59.95. This light pipe will transmit light for angles of incidence greater than 59.95
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.56
# Angle: 59.32. This light pipe will transmit light for angles of incidence greater than 59.32
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.57
# Angle: 58.7. This light pipe will transmit light for angles of incidence greater than 58.7
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.58
# Angle: 58.11. This light pipe will transmit light for angles of incidence greater than 58.11
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.59
# Angle: 57.53. This light pipe will transmit light for angles of incidence greater than 57.53
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.6
# Angle: 56.97. This light pipe will transmit light for angles of incidence greater than 56.97
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.61
# Angle: 56.42. This light pipe will transmit light for angles of incidence greater than 56.42
#
# Light is transmitted
# for rod index Water: 1.333 and index Crown glass: 1.62
# Angle: 55.89. This light pipe will transmit light for angles of incidence greater than 55.89
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.57
# Angle: 55.37. This light pipe will transmit light for angles of incidence greater than 55.37
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.58
# Angle: 58.11. This light pipe will transmit light for angles of incidence greater than 58.11
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.59
# Angle: 57.53. This light pipe will transmit light for angles of incidence greater than 57.53
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6
# Angle: 56.97. This light pipe will transmit light for angles of incidence greater than 56.97
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.61
# Angle: 56.42. This light pipe will transmit light for angles of incidence greater than 56.42
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.62
# Angle: 55.89. This light pipe will transmit light for angles of incidence greater than 55.89
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6300000000000001
# Angle: 55.37. This light pipe will transmit light for angles of incidence greater than 55.37
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6400000000000001
# Angle: 54.86. This light pipe will transmit light for angles of incidence greater than 54.86
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6500000000000001
# Angle: 54.37. This light pipe will transmit light for angles of incidence greater than 54.37
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6600000000000001
# Angle: 53.89. This light pipe will transmit light for angles of incidence greater than 53.89
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6700000000000002
# Angle: 53.42. This light pipe will transmit light for angles of incidence greater than 53.42
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6800000000000002
# Angle: 52.96. This light pipe will transmit light for angles of incidence greater than 52.96
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.6900000000000002
# Angle: 52.51. This light pipe will transmit light for angles of incidence greater than 52.51
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.7000000000000002
# Angle: 52.07. This light pipe will transmit light for angles of incidence greater than 52.07
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.7100000000000002
# Angle: 51.64. This light pipe will transmit light for angles of incidence greater than 51.64
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.7200000000000002
# Angle: 51.22. This light pipe will transmit light for angles of incidence greater than 51.22
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.7300000000000002
# Angle: 50.81. This light pipe will transmit light for angles of incidence greater than 50.81
#
# Light is transmitted
# for rod index Water: 1.333 and index Flint glass: 1.7400000000000002
# Angle: 50.4. This light pipe will transmit light for angles of incidence greater than 50.4
#
# Light is transmitted
# for rod index Water: 1.333 and index Diamond: 2.417
# Angle: 50.0. This light pipe will transmit light for angles of incidence greater than 50.0
#
# Light is transmitted
# for rod index Water: 1.333 and index Acrylic: 1.49
# Angle: 33.47. This light pipe will transmit light for angles of incidence greater than 33.47
#
# Light is not transmitted
# for rod index Ethyl Alcohol: 1.362 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Ethyl Alcohol: 1.362 and index Air: 1.0003
#
# Light is not transmitted
# for rod index Ethyl Alcohol: 1.362 and index Carbon dioxide: 1.0005
#
# Light is not transmitted
# for rod index Ethyl Alcohol: 1.362 and index Water: 1.333
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Glycerine: 1.473
# Angle: 63.46. This light pipe will transmit light for angles of incidence greater than 63.46
#
# Light is not transmitted
# for rod index Ethyl Alcohol: 1.362 and index Ice: 1.31
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Polystyrene: 1.59
# Angle: 67.61. This light pipe will transmit light for angles of incidence greater than 67.61
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.5
# Angle: 58.94. This light pipe will transmit light for angles of incidence greater than 58.94
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.51
# Angle: 65.23. This light pipe will transmit light for angles of incidence greater than 65.23
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.52
# Angle: 64.42. This light pipe will transmit light for angles of incidence greater than 64.42
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.53
# Angle: 63.64. This light pipe will transmit light for angles of incidence greater than 63.64
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.54
# Angle: 62.9. This light pipe will transmit light for angles of incidence greater than 62.9
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.55
# Angle: 62.18. This light pipe will transmit light for angles of incidence greater than 62.18
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.56
# Angle: 61.49. This light pipe will transmit light for angles of incidence greater than 61.49
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.57
# Angle: 60.82. This light pipe will transmit light for angles of incidence greater than 60.82
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.58
# Angle: 60.17. This light pipe will transmit light for angles of incidence greater than 60.17
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.59
# Angle: 59.54. This light pipe will transmit light for angles of incidence greater than 59.54
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.6
# Angle: 58.94. This light pipe will transmit light for angles of incidence greater than 58.94
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.61
# Angle: 58.35. This light pipe will transmit light for angles of incidence greater than 58.35
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Crown glass: 1.62
# Angle: 57.78. This light pipe will transmit light for angles of incidence greater than 57.78
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.57
# Angle: 57.22. This light pipe will transmit light for angles of incidence greater than 57.22
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.58
# Angle: 60.17. This light pipe will transmit light for angles of incidence greater than 60.17
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.59
# Angle: 59.54. This light pipe will transmit light for angles of incidence greater than 59.54
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6
# Angle: 58.94. This light pipe will transmit light for angles of incidence greater than 58.94
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.61
# Angle: 58.35. This light pipe will transmit light for angles of incidence greater than 58.35
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.62
# Angle: 57.78. This light pipe will transmit light for angles of incidence greater than 57.78
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6300000000000001
# Angle: 57.22. This light pipe will transmit light for angles of incidence greater than 57.22
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6400000000000001
# Angle: 56.68. This light pipe will transmit light for angles of incidence greater than 56.68
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6500000000000001
# Angle: 56.15. This light pipe will transmit light for angles of incidence greater than 56.15
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6600000000000001
# Angle: 55.63. This light pipe will transmit light for angles of incidence greater than 55.63
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6700000000000002
# Angle: 55.13. This light pipe will transmit light for angles of incidence greater than 55.13
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6800000000000002
# Angle: 54.64. This light pipe will transmit light for angles of incidence greater than 54.64
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.6900000000000002
# Angle: 54.17. This light pipe will transmit light for angles of incidence greater than 54.17
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.7000000000000002
# Angle: 53.7. This light pipe will transmit light for angles of incidence greater than 53.7
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.7100000000000002
# Angle: 53.24. This light pipe will transmit light for angles of incidence greater than 53.24
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.7200000000000002
# Angle: 52.8. This light pipe will transmit light for angles of incidence greater than 52.8
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.7300000000000002
# Angle: 52.36. This light pipe will transmit light for angles of incidence greater than 52.36
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Flint glass: 1.7400000000000002
# Angle: 51.93. This light pipe will transmit light for angles of incidence greater than 51.93
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Diamond: 2.417
# Angle: 51.51. This light pipe will transmit light for angles of incidence greater than 51.51
#
# Light is transmitted
# for rod index Ethyl Alcohol: 1.362 and index Acrylic: 1.49
# Angle: 34.3. This light pipe will transmit light for angles of incidence greater than 34.3
#
# Light is not transmitted
# for rod index Glycerine: 1.473 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Glycerine: 1.473 and index Air: 1.0003
#
# Light is not transmitted
# for rod index Glycerine: 1.473 and index Carbon dioxide: 1.0005
#
# Light is not transmitted
# for rod index Glycerine: 1.473 and index Water: 1.333
#
# Light is not transmitted
# for rod index Glycerine: 1.473 and index Ethyl Alcohol: 1.362
#
# Light is not transmitted
# for rod index Glycerine: 1.473 and index Ice: 1.31
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Polystyrene: 1.59
# Angle: 66.08. This light pipe will transmit light for angles of incidence greater than 66.08
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.5
# Angle: 67.88. This light pipe will transmit light for angles of incidence greater than 67.88
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.51
# Angle: 79.11. This light pipe will transmit light for angles of incidence greater than 79.11
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.52
# Angle: 77.29. This light pipe will transmit light for angles of incidence greater than 77.29
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.53
# Angle: 75.71. This light pipe will transmit light for angles of incidence greater than 75.71
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.54
# Angle: 74.31. This light pipe will transmit light for angles of incidence greater than 74.31
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.55
# Angle: 73.04. This light pipe will transmit light for angles of incidence greater than 73.04
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.56
# Angle: 71.86. This light pipe will transmit light for angles of incidence greater than 71.86
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.57
# Angle: 70.77. This light pipe will transmit light for angles of incidence greater than 70.77
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.58
# Angle: 69.75. This light pipe will transmit light for angles of incidence greater than 69.75
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.59
# Angle: 68.79. This light pipe will transmit light for angles of incidence greater than 68.79
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.6
# Angle: 67.88. This light pipe will transmit light for angles of incidence greater than 67.88
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.61
# Angle: 67.02. This light pipe will transmit light for angles of incidence greater than 67.02
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Crown glass: 1.62
# Angle: 66.19. This light pipe will transmit light for angles of incidence greater than 66.19
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.57
# Angle: 65.4. This light pipe will transmit light for angles of incidence greater than 65.4
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.58
# Angle: 69.75. This light pipe will transmit light for angles of incidence greater than 69.75
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.59
# Angle: 68.79. This light pipe will transmit light for angles of incidence greater than 68.79
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6
# Angle: 67.88. This light pipe will transmit light for angles of incidence greater than 67.88
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.61
# Angle: 67.02. This light pipe will transmit light for angles of incidence greater than 67.02
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.62
# Angle: 66.19. This light pipe will transmit light for angles of incidence greater than 66.19
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6300000000000001
# Angle: 65.4. This light pipe will transmit light for angles of incidence greater than 65.4
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6400000000000001
# Angle: 64.65. This light pipe will transmit light for angles of incidence greater than 64.65
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6500000000000001
# Angle: 63.92. This light pipe will transmit light for angles of incidence greater than 63.92
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6600000000000001
# Angle: 63.22. This light pipe will transmit light for angles of incidence greater than 63.22
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6700000000000002
# Angle: 62.54. This light pipe will transmit light for angles of incidence greater than 62.54
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6800000000000002
# Angle: 61.89. This light pipe will transmit light for angles of incidence greater than 61.89
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.6900000000000002
# Angle: 61.26. This light pipe will transmit light for angles of incidence greater than 61.26
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.7000000000000002
# Angle: 60.64. This light pipe will transmit light for angles of incidence greater than 60.64
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.7100000000000002
# Angle: 60.05. This light pipe will transmit light for angles of incidence greater than 60.05
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.7200000000000002
# Angle: 59.47. This light pipe will transmit light for angles of incidence greater than 59.47
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.7300000000000002
# Angle: 58.91. This light pipe will transmit light for angles of incidence greater than 58.91
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Flint glass: 1.7400000000000002
# Angle: 58.37. This light pipe will transmit light for angles of incidence greater than 58.37
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Diamond: 2.417
# Angle: 57.84. This light pipe will transmit light for angles of incidence greater than 57.84
#
# Light is transmitted
# for rod index Glycerine: 1.473 and index Acrylic: 1.49
# Angle: 37.55. This light pipe will transmit light for angles of incidence greater than 37.55
#
# Light is not transmitted
# for rod index Ice: 1.31 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Ice: 1.31 and index Air: 1.0003
#
# Light is not transmitted
# for rod index Ice: 1.31 and index Carbon dioxide: 1.0005
#
# Light is transmitted
# for rod index Ice: 1.31 and index Water: 1.333
# Angle: 81.34. This light pipe will transmit light for angles of incidence greater than 81.34
#
# Light is transmitted
# for rod index Ice: 1.31 and index Ethyl Alcohol: 1.362
# Angle: 79.34. This light pipe will transmit light for angles of incidence greater than 79.34
#
# Light is transmitted
# for rod index Ice: 1.31 and index Glycerine: 1.473
# Angle: 74.12. This light pipe will transmit light for angles of incidence greater than 74.12
#
# Light is transmitted
# for rod index Ice: 1.31 and index Polystyrene: 1.59
# Angle: 62.79. This light pipe will transmit light for angles of incidence greater than 62.79
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.5
# Angle: 55.48. This light pipe will transmit light for angles of incidence greater than 55.48
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.51
# Angle: 60.85. This light pipe will transmit light for angles of incidence greater than 60.85
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.52
# Angle: 60.18. This light pipe will transmit light for angles of incidence greater than 60.18
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.53
# Angle: 59.52. This light pipe will transmit light for angles of incidence greater than 59.52
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.54
# Angle: 58.89. This light pipe will transmit light for angles of incidence greater than 58.89
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.55
# Angle: 58.28. This light pipe will transmit light for angles of incidence greater than 58.28
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.56
# Angle: 57.69. This light pipe will transmit light for angles of incidence greater than 57.69
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.57
# Angle: 57.11. This light pipe will transmit light for angles of incidence greater than 57.11
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.58
# Angle: 56.55. This light pipe will transmit light for angles of incidence greater than 56.55
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.59
# Angle: 56.01. This light pipe will transmit light for angles of incidence greater than 56.01
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.6
# Angle: 55.48. This light pipe will transmit light for angles of incidence greater than 55.48
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.61
# Angle: 54.96. This light pipe will transmit light for angles of incidence greater than 54.96
#
# Light is transmitted
# for rod index Ice: 1.31 and index Crown glass: 1.62
# Angle: 54.46. This light pipe will transmit light for angles of incidence greater than 54.46
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.57
# Angle: 53.96. This light pipe will transmit light for angles of incidence greater than 53.96
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.58
# Angle: 56.55. This light pipe will transmit light for angles of incidence greater than 56.55
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.59
# Angle: 56.01. This light pipe will transmit light for angles of incidence greater than 56.01
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6
# Angle: 55.48. This light pipe will transmit light for angles of incidence greater than 55.48
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.61
# Angle: 54.96. This light pipe will transmit light for angles of incidence greater than 54.96
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.62
# Angle: 54.46. This light pipe will transmit light for angles of incidence greater than 54.46
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6300000000000001
# Angle: 53.96. This light pipe will transmit light for angles of incidence greater than 53.96
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6400000000000001
# Angle: 53.48. This light pipe will transmit light for angles of incidence greater than 53.48
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6500000000000001
# Angle: 53.01. This light pipe will transmit light for angles of incidence greater than 53.01
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6600000000000001
# Angle: 52.56. This light pipe will transmit light for angles of incidence greater than 52.56
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6700000000000002
# Angle: 52.11. This light pipe will transmit light for angles of incidence greater than 52.11
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6800000000000002
# Angle: 51.67. This light pipe will transmit light for angles of incidence greater than 51.67
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.6900000000000002
# Angle: 51.24. This light pipe will transmit light for angles of incidence greater than 51.24
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.7000000000000002
# Angle: 50.82. This light pipe will transmit light for angles of incidence greater than 50.82
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.7100000000000002
# Angle: 50.41. This light pipe will transmit light for angles of incidence greater than 50.41
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.7200000000000002
# Angle: 50.0. This light pipe will transmit light for angles of incidence greater than 50.0
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.7300000000000002
# Angle: 49.61. This light pipe will transmit light for angles of incidence greater than 49.61
#
# Light is transmitted
# for rod index Ice: 1.31 and index Flint glass: 1.7400000000000002
# Angle: 49.22. This light pipe will transmit light for angles of incidence greater than 49.22
#
# Light is transmitted
# for rod index Ice: 1.31 and index Diamond: 2.417
# Angle: 48.84. This light pipe will transmit light for angles of incidence greater than 48.84
#
# Light is transmitted
# for rod index Ice: 1.31 and index Acrylic: 1.49
# Angle: 32.82. This light pipe will transmit light for angles of incidence greater than 32.82
#
# Light is not transmitted
# for rod index Polystyrene: 1.59 and index Hydrogen: 1.0001
#
# Light is not transmitted
# ...
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.6300000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.6400000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.6500000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.6600000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.6700000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.6800000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.6900000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.7000000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.7100000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.7200000000000002
#
# Light is transmitted
# for rod index Flint glass: 1.7300000000000002 and index Flint glass: 1.7400000000000002
# Angle: 45.37. This light pipe will transmit light for angles of incidence greater than 45.37
#
# Light is transmitted
# for rod index Flint glass: 1.7300000000000002 and index Diamond: 2.417
# Angle: 83.85. This light pipe will transmit light for angles of incidence greater than 83.85
#
# Light is not transmitted
# for rod index Flint glass: 1.7300000000000002 and index Acrylic: 1.49
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Air: 1.0003
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Carbon dioxide: 1.0005
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Water: 1.333
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Ethyl Alcohol: 1.362
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Glycerine: 1.473
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Ice: 1.31
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Polystyrene: 1.59
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.5
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.51
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.52
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.53
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.54
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.55
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.56
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.57
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.58
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.59
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.6
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.61
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Crown glass: 1.62
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.57
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.58
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.59
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.61
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.62
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6300000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6400000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6500000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6600000000000001
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6700000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6800000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.6900000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.7000000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.7100000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.7200000000000002
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Flint glass: 1.7300000000000002
#
# Light is transmitted
# for rod index Flint glass: 1.7400000000000002 and index Diamond: 2.417
# Angle: 45.71. This light pipe will transmit light for angles of incidence greater than 45.71
#
# Light is not transmitted
# for rod index Flint glass: 1.7400000000000002 and index Acrylic: 1.49
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Air: 1.0003
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Carbon dioxide: 1.0005
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Water: 1.333
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Ethyl Alcohol: 1.362
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Glycerine: 1.473
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Ice: 1.31
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Polystyrene: 1.59
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.5
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.51
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.52
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.53
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.54
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.55
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.56
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.57
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.58
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.59
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.6
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.61
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Crown glass: 1.62
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.57
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.58
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.59
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.61
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.62
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6300000000000001
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6400000000000001
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6500000000000001
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6600000000000001
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6700000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6800000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.6900000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.7000000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.7100000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.7200000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.7300000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Flint glass: 1.7400000000000002
#
# Light is not transmitted
# for rod index Diamond: 2.417 and index Acrylic: 1.49
#
# Light is not transmitted
# for rod index Acrylic: 1.49 and index Hydrogen: 1.0001
#
# Light is not transmitted
# for rod index Acrylic: 1.49 and index Air: 1.0003
#
# Light is not transmitted
# for rod index Acrylic: 1.49 and index Carbon dioxide: 1.0005
#
# Light is not transmitted
# for rod index Acrylic: 1.49 and index Water: 1.333
#
# Light is not transmitted
# for rod index Acrylic: 1.49 and index Ethyl Alcohol: 1.362
#
# Light is not transmitted
# for rod index Acrylic: 1.49 and index Glycerine: 1.473
#
# Light is not transmitted
# for rod index Acrylic: 1.49 and index Ice: 1.31
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Polystyrene: 1.59
# Angle: 46.05. This light pipe will transmit light for angles of incidence greater than 46.05
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.5
# Angle: 69.57. This light pipe will transmit light for angles of incidence greater than 69.57
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.51
# Angle: 83.38. This light pipe will transmit light for angles of incidence greater than 83.38
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.52
# Angle: 80.66. This light pipe will transmit light for angles of incidence greater than 80.66
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.53
# Angle: 78.6. This light pipe will transmit light for angles of incidence greater than 78.6
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.54
# Angle: 76.87. This light pipe will transmit light for angles of incidence greater than 76.87
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.55
# Angle: 75.36. This light pipe will transmit light for angles of incidence greater than 75.36
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.56
# Angle: 74.01. This light pipe will transmit light for angles of incidence greater than 74.01
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.57
# Angle: 72.77. This light pipe will transmit light for angles of incidence greater than 72.77
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.58
# Angle: 71.63. This light pipe will transmit light for angles of incidence greater than 71.63
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.59
# Angle: 70.57. This light pipe will transmit light for angles of incidence greater than 70.57
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.6
# Angle: 69.57. This light pipe will transmit light for angles of incidence greater than 69.57
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.61
# Angle: 68.63. This light pipe will transmit light for angles of incidence greater than 68.63
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Crown glass: 1.62
# Angle: 67.74. This light pipe will transmit light for angles of incidence greater than 67.74
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.57
# Angle: 66.89. This light pipe will transmit light for angles of incidence greater than 66.89
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.58
# Angle: 71.63. This light pipe will transmit light for angles of incidence greater than 71.63
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.59
# Angle: 70.57. This light pipe will transmit light for angles of incidence greater than 70.57
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6
# Angle: 69.57. This light pipe will transmit light for angles of incidence greater than 69.57
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.61
# Angle: 68.63. This light pipe will transmit light for angles of incidence greater than 68.63
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.62
# Angle: 67.74. This light pipe will transmit light for angles of incidence greater than 67.74
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6300000000000001
# Angle: 66.89. This light pipe will transmit light for angles of incidence greater than 66.89
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6400000000000001
# Angle: 66.08. This light pipe will transmit light for angles of incidence greater than 66.08
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6500000000000001
# Angle: 65.3. This light pipe will transmit light for angles of incidence greater than 65.3
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6600000000000001
# Angle: 64.56. This light pipe will transmit light for angles of incidence greater than 64.56
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6700000000000002
# Angle: 63.84. This light pipe will transmit light for angles of incidence greater than 63.84
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6800000000000002
# Angle: 63.15. This light pipe will transmit light for angles of incidence greater than 63.15
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.6900000000000002
# Angle: 62.49. This light pipe will transmit light for angles of incidence greater than 62.49
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.7000000000000002
# Angle: 61.84. This light pipe will transmit light for angles of incidence greater than 61.84
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.7100000000000002
# Angle: 61.22. This light pipe will transmit light for angles of incidence greater than 61.22
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.7200000000000002
# Angle: 60.62. This light pipe will transmit light for angles of incidence greater than 60.62
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.7300000000000002
# Angle: 60.03. This light pipe will transmit light for angles of incidence greater than 60.03
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Flint glass: 1.7400000000000002
# Angle: 59.46. This light pipe will transmit light for angles of incidence greater than 59.46
#
# Light is transmitted
# for rod index Acrylic: 1.49 and index Diamond: 2.417
# Angle: 58.91. This light pipe will transmit light for angles of incidence greater than 58.91
#
# Here we can see that from 1640 the combinations 812 do not transmit light, but 828 have the ability to transmit light.

# %% [markdown]
# ## Conclusion
# Having studied the results, we can conclude that not all the combinations what we used give us, a positive result, only 828 out of 1640

# %% [markdown]
# ## Materials

# %% [markdown]
# Fiber optics (optical fiber)
# https://searchnetworking.techtarget.com/definition/fiber-optics-optical-fiber
#
# First picture
# https://3.imimg.com/data3/SO/HU/MY-3400599/lite-500x500.png
#
# Second picture
# http://oer2go.org/mods/en-boundless/figures.boundless-cdn.com/17012/large/figure-2026-04-04.jpeg
